# %%
import osmnx as ox
import networkx as nx
import plotly.graph_objects as go
import numpy as np

# %%
G = ox.graph_from_place('Nairobi, Kenia', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
nodes, edges = ox.graph_to_gdfs(G)
nodes.head()
# Out:
#                  y          x     osmid   ref            highway  \
# 29780039 -1.344646  36.914422  29780039   NaN                NaN
# 29780051 -1.347919  36.909213  29780051  23-D  motorway_junction
# 30030168 -1.289755  36.798038  30030168   NaN                NaN
# 30030170 -1.294801  36.800292  30030170   NaN                NaN
# 30030172 -1.285639  36.804942  30030172   NaN                NaN
#
#                            geometry
# 29780039  POINT (36.91442 -1.34465)
# 29780051  POINT (36.90921 -1.34792)
# 30030168  POINT (36.79804 -1.28975)
# 30030170  POINT (36.80029 -1.29480)
# 30030172  POINT (36.80494 -1.28564)

# %%
edges.head()
# Out:
#                   osmid  oneway   ref     highway   length  \
# 0               4685092    True  B10E   secondary  329.148
# 1               4962926    True  B10E   secondary   69.913
# 2  [4685092, 663223989]    True  B10E   secondary  832.899
# 3              25739466    True   NaN  trunk_link  675.319
# 4               4741880   False   NaN    tertiary  394.649
#
#                                             geometry    junction  \
# 0  LINESTRING (36.91442 -1.34465, 36.91427 -1.344...         NaN
# 1  LINESTRING (36.91442 -1.34465, 36.91430 -1.344...  roundabout
# 2  LINESTRING (36.90921 -1.34792, 36.90851 -1.348...         NaN
# 3  LINESTRING (36.90921 -1.34792, 36.90882 -1.348...         NaN
# 4  LINESTRING (36.79804 -1.28975, 36.79820 -1.290...         NaN
#
#              name maxspeed lanes access bridge tunnel width service         u  \
# 0             NaN      NaN   NaN    NaN    NaN    NaN   NaN     NaN  29780039
# ...
